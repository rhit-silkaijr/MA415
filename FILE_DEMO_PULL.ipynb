# %%
import numpy as np
import pandas as pd

# %%
# Bringing in the Data

# read data
df = pd.read_csv('LassoFeatures.csv')
df = df.drop('Unnamed: 0',axis=1)
print(df.shape)
df.head(3)
# Out:
# (15351, 41)
#    disc_year  sy_snum glon st_rad  sy_pnum glon ra  sy_pnum dec sy_pm  \
# 0   0.132709             1.109439        -1.246369           0.072314
# 1   0.132709             1.038075        -1.246369           0.072314
# 2   2.065912             2.937174         1.971716          -0.623103
#
#    sy_pnum dec sy_plx  sy_pnum elat sy_pm  sy_pnum elat sy_plx  \
# 0           -0.212191           -0.668538            -0.633221
# 1           -0.212191           -0.668538            -0.633221
# 2           -0.582859           -0.635000            -0.578307
#
#    sy_pnum elat st_teff  sy_pnum pl_ntranspec st_rad  \
# 0             -1.490701                    -0.140779
# 1             -1.490521                    -0.140779
# 2             -1.425261                    -0.140779
#
#    sy_pnum st_rad pl_orbper  ...  disc_year st_rad pl_orbper  \
# 0                 -0.107814  ...                    0.194529
# 1                 -0.115598  ...                    0.175636
# ...
