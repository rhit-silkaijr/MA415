# %% [markdown]
# CSSE/MA 415
# Team 02: Michael Owens, Lance Fowler, Jack Silkaitis

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# Bringing in the Data

# %%
df = pd.read_csv('ExoplanetArchiveAllClean.csv')
df.head(1)
# Out:
# C:\Users\owensmt\AppData\Local\Temp\ipykernel_20496\832195803.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ExoplanetArchiveAllClean.csv')
#    rowid   pl_name hostname pl_letter    hd_name   hip_name        tic_id  \
# 0      1  11 Com b   11 Com         b  HD 107383  HIP 60202  TIC 72437047
#
#                     gaia_dr2_id                   gaia_dr3_id  default_flag  \
# 0  Gaia DR2 3946945413106333696  Gaia DR3 3946945413106333696             1
#
#    ...  rowupdate  pl_pubdate  releasedate  pl_nnotes st_nphot  st_nrvc  \
# 0  ...  9/19/2023     2023-12    9/19/2023          2        1        2
#
#   st_nspec pl_nespec pl_ntranspec pl_ndispec
# 0        0         0            0          0
#
# [1 rows x 289 columns]

# %%
df.shape
# Out:
# (39816, 289)

# %%
df.value_counts(df['pl_name'])
# Out:
# pl_name
# TrES-2 b            34
# Kepler-10 b         25
# GJ 436 b            24
# HAT-P-7 b           24
# HD 209458 b         23
#                     ..
# ZTF J1828+2308 b     1
# alf Ari b            1
# alf Tau b            1
# b Cen AB b           1
# bet Cnc b            1
# Name: count, Length: 6278, dtype: int64

# %%
# Out:
# pl_msinie
# 4.0000      7
# 6.3566      6
# 6.6000      5
# 511.7063    5
# 127.1320    5
#            ..
# 0.9800      1
# 1.0000      1
# 1.0300      1
# 6.2000      1
# 0.1930      1
# Name: count, Length: 2193, dtype: int64
