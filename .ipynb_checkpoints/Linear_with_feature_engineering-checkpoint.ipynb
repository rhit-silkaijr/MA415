# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate, train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
import plotly.express as px

# %%
df = pd.read_csv("CleanPreprocessedExoplanet.csv")
df.head()
# Out:
#    Unnamed: 0  release_month  pl_nnotes  pl_controv_flag     elat       elon  \
# 0         224              2          1                0  1.31208   56.28872
# 1         225              7          1                0  1.31208   56.28872
# 2         449              8          0                0  3.28517  182.62760
# 3         487             12          1                0 -0.60769  128.15245
# 4         489             10          1                0 -0.60769  128.15245
#
#        glat  cb_flag       glon          ra  ...  disc_facility_HATNet  \
# 0 -28.05348        0  166.79660   53.651123  ...                 False
# 1 -28.05348        0  166.79660   53.651123  ...                 False
# 2  63.35883        0  282.19917  183.720363  ...                 False
# 3  32.03739        0  208.28299  130.410209  ...                 False
# 4  32.03739        0  208.28299  130.410209  ...                 False
#
#    disc_facility_HATSouth  disc_facility_K2  disc_facility_Kepler  \
# 0                   False              True                 False
# 1                   False              True                 False
# 2                   False              True                 False
# 3                   False              True                 False
# 4                   False              True                 False
#
#    disc_facility_Qatar  disc_facility_SuperWASP  \
# 0                False                    False
# 1                False                    False
# 2                False                    False
# 3                False                    False
# 4                False                    False
#
#    disc_facility_SuperWASP-South  disc_facility_TrES  disc_locale_Ground  \
# 0                          False               False               False
# 1                          False               False               False
# 2                          False               False               False
# 3                          False               False               False
# 4                          False               False               False
#
#    disc_locale_Space
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
#
# [5 rows x 73 columns]
